# %%
# %load_ext autoreload 
# %autoreload 2
import os, sys
import pandas as pd 
import numpy as np 
sys.path.append('../')
from util_preprocess.fuctions import *
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Read data

# %%
df = pd.read_hdf('../currency_data/currency.h5')

df['USD_NTD']  = df['美元／新台幣']
df['RMD_NTD']  = df['人民幣／新台幣']
df['UD_USD'] = df['歐元／美元']
df['USD_JPD'] = df['美元／日幣']
df['USD_RMB'] = df['美元／人民幣']
df['END_USD'] = df["英鎊／美元"]
del df['美元／新台幣']
del df['人民幣／新台幣']
del df['歐元／美元']
del df['美元／日幣']
del df['美元／人民幣']
del  df["英鎊／美元"]
df.set_index('日期', inplace=True)
df.index = pd.to_datetime(df.index)

# %%
df = df.sort_index()
df['USD_NTD_Trend'] = trend(list(df['USD_NTD']))
df['USD_NTD_Label'] = trend_2(list(df['USD_NTD']))
df.head()
# Out:
#               澳幣／美元    美元／港幣    美元／南非幣  紐幣／美元  USD_NTD   RMD_NTD   UD_USD  \
# 日期
# 2016-01-04  0.72130  7.75085  15.63855    NaN   33.236  5.023356  1.09265
# 2016-01-05  0.72075  7.75100  15.58535    NaN   33.270  5.009630  1.08150
# 2016-01-06  0.71020  7.75150  15.75085    NaN   33.453  4.990585  1.07355
# 2016-01-07  0.70555  7.75220  15.98500    NaN   33.530  5.012467  1.07785
# 2016-01-08  0.70340  7.75760  16.03800    NaN   33.501  5.011080  1.08930
#
#             USD_JPD  USD_RMB  END_USD  USD_NTD_Trend  USD_NTD_Label
# 日期
# 2016-01-04  118.855   6.6163   1.4760              0              0
# 2016-01-05  119.255   6.6412   1.4713              1              1
# 2016-01-06  118.635   6.7032   1.4636              2              1
# 2016-01-07  118.095   6.6893   1.4593              3              1
# 2016-01-08  118.265   6.6854   1.4616              2              0

# %%
#df['USD_NTD'].plot()
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import f1_score
df.head()
col = ["USD_NTD", "RMD_NTD","UD_USD","USD_JPD","USD_RMB","USD_NTD_Trend"]


train_df = df.copy()

# %%
# previous_Ndays_price([1, 2, 4, 5, 6, 7, 8], 3)
for N in [ 5, 9]:
    for c in col:
        train_df[c+'_pre_d{}'.format(N)] = previous_Ndays_price_delta( list( train_df[c]), N)
        train_df[c+'_pre_{}'.format(N)] = previous_Ndays_price( list( train_df[c]), N)
        train_df[c+'_pre_dp[{}'.format(N)] = previous_Ndays_price_delta_percent( list( train_df[c]), N)

# %%
# alone time convolution

# %%
col = [i for i in train_df.columns if i not in ['USD_NTD_Label', 
                                                '紐幣／美元', 
                                                '澳幣／美元',
                                                '美元／港幣']]
display(train_df[col][9:].head())
X = train_df[col].values[9:-1]
y = train_df["USD_NTD_Label"].values[9+1:]
y_5days = up_within_Ndays(y)
y_3days = up_within_Ndays(y, 3)
y_2days = up_within_Ndays(y, 2)
# Out:
#               美元／南非幣  USD_NTD   RMD_NTD   UD_USD  USD_JPD  USD_RMB  END_USD  \
# 日期
# 2016-01-15  16.56000   33.802  5.106570  1.08835  117.610   6.6193   1.4393
# 2016-01-18  16.74385   33.818  5.127756  1.08835  117.245   6.5951   1.4297
# 2016-01-19  16.59670   33.820  5.124305  1.08755  117.945   6.5999   1.4300
# 2016-01-20  16.82140   33.826  5.124064  1.09505  116.725   6.6014   1.4168
# 2016-01-21  16.73580   33.838  5.117591  1.08935  117.065   6.6121   1.4167
#
#             USD_NTD_Trend  USD_NTD_pre_d5  USD_NTD_pre_5  \
# 日期
# 2016-01-15              5          -0.301         33.501
# 2016-01-18              6          -0.167         33.651
# 2016-01-19              7          -0.153         33.667
# 2016-01-20              8          -0.201         33.625
# 2016-01-21              9          -0.096         33.742
#
#                      ...            UD_USD_pre_dp[9  USD_JPD_pre_d9  \
# 日期                   ...
# 2016-01-15           ...                   0.003951           1.245
# 2016-01-18           ...                  -0.006294           2.010
# 2016-01-19           ...                  -0.012873           0.690
# 2016-01-20           ...                  -0.015707           1.370
# 2016-01-21           ...                  -0.000046           1.200
#
#             USD_JPD_pre_9  USD_JPD_pre_dp[9  USD_RMB_pre_d9  USD_RMB_pre_9  \
# 日期
# 2016-01-15        118.855          0.010586         -0.0030         6.6163
# 2016-01-18        119.255          0.017144          0.0461         6.6412
# 2016-01-19        118.635          0.005850          0.1033         6.7032
# 2016-01-20        118.095          0.011737          0.0879         6.6893
# 2016-01-21        118.265          0.010251          0.0733         6.6854
#
#             USD_RMB_pre_dp[9  USD_NTD_Trend_pre_d9  USD_NTD_Trend_pre_9  \
# 日期
# 2016-01-15         -0.000453                  -5.0                  0.0
# 2016-01-18          0.006990                  -5.0                  1.0
# 2016-01-19          0.015652                  -5.0                  2.0
# 2016-01-20          0.013315                  -5.0                  3.0
# 2016-01-21          0.011086                  -7.0                  2.0
#
#             USD_NTD_Trend_pre_dp[9
# 日期
# 2016-01-15               -1.000000
# 2016-01-18               -0.833333
# 2016-01-19               -0.714286
# 2016-01-20               -0.625000
# 2016-01-21               -0.777778
#
# [5 rows x 44 columns]

# %%
def kflod_trainer(X, y, model, nsplit=3, feats=col):
    fold = StratifiedKFold(nsplit)
    for train_ind, valid_ind in fold.split(X, y):
        trX, trY = X[train_ind], y[train_ind]
        vaX, vaY = X[valid_ind], y[valid_ind]
        model.fit(trX, trY)
        pre_y = model.predict(vaX)
        loss = classification_report(vaY, pre_y, )
        print('----------------------------------------------------------------')
        print(loss)
        res_df = pd.DataFrame()
        res_df['feats'] = feats
        res_df.index = [round(i, 3) for i in 
                        list(model.feature_importances_)]
        display(res_df.sort_index())
for i in [2, 3, 4]:
    kflod_trainer(X, y_2days, GradientBoostingClassifier(max_depth=2 ), i)
# kflod_trainer(X, y_2days, LogisticRegression(C=0.1 ), 2)
# Out:
# ----------------------------------------------------------------
#              precision    recall  f1-score   support
#
#         0.0       0.17      0.67      0.27        27
#         1.0       0.82      0.32      0.46       127
#
# avg / total       0.71      0.38      0.43       154
#                         feats
# 0.000    USD_NTD_Trend_pre_d9
# 0.000                 RMD_NTD
# 0.000          USD_RMB_pre_d5
# 0.000                 USD_JPD
# 0.000                 USD_RMB
# 0.000           USD_RMB_pre_9
# 0.000        USD_JPD_pre_dp[9
# 0.000        USD_NTD_pre_dp[5
# 0.000        USD_RMB_pre_dp[5
# 0.000  USD_NTD_Trend_pre_dp[5
# 0.005          USD_JPD_pre_d9
# 0.005          USD_RMB_pre_d9
# 0.005          USD_NTD_pre_d5
# 0.005     USD_NTD_Trend_pre_5
# 0.006           USD_NTD_pre_9
# 0.006  USD_NTD_Trend_pre_dp[9
# 0.006           UD_USD_pre_d5
# 0.009           RMD_NTD_pre_9
# 0.009        USD_JPD_pre_dp[5
# 0.010    USD_NTD_Trend_pre_d5
# 0.011           USD_JPD_pre_5
# 0.013     USD_NTD_Trend_pre_9
# 0.015          RMD_NTD_pre_d9
# 0.015                  UD_USD
# 0.016           USD_RMB_pre_5
# 0.016            UD_USD_pre_5
# 0.020           UD_USD_pre_d9
# 0.023        RMD_NTD_pre_dp[9
# 0.024         UD_USD_pre_dp[5
# 0.025        USD_RMB_pre_dp[9
# 0.027                 USD_NTD
# 0.030           USD_NTD_pre_5
# 0.030          USD_JPD_pre_d5
# 0.030         UD_USD_pre_dp[9
# 0.033           USD_JPD_pre_9
# 0.036        RMD_NTD_pre_dp[5
# 0.043            UD_USD_pre_9
# 0.047                 END_USD
# 0.052           RMD_NTD_pre_5
# 0.055           USD_NTD_Trend
# 0.068          USD_NTD_pre_d9
# 0.084        USD_NTD_pre_dp[9
# 0.095          RMD_NTD_pre_d5
# 0.127                  美元／南非幣
# ----------------------------------------------------------------
#              precision    recall  f1-score   support
#
#         0.0       0.18      0.88      0.30        26
#         1.0       0.88      0.18      0.30       126
#
# avg / total       0.76      0.30      0.30       152
#                         feats
# 0.000        USD_RMB_pre_dp[9
# 0.000          USD_RMB_pre_d9
# 0.000           USD_JPD_pre_9
# 0.000    USD_NTD_Trend_pre_d9
# 0.000    USD_NTD_Trend_pre_d5
# 0.000           USD_JPD_pre_5
# 0.000           USD_NTD_Trend
# 0.001           UD_USD_pre_d9
# 0.003         UD_USD_pre_dp[5
# 0.003                  美元／南非幣
# 0.004  USD_NTD_Trend_pre_dp[5
# 0.004            UD_USD_pre_9
# 0.004          USD_NTD_pre_d9
# 0.005                 USD_RMB
# 0.006                 RMD_NTD
# 0.006          USD_RMB_pre_d5
# 0.008         UD_USD_pre_dp[9
# 0.008                  UD_USD
# 0.011          RMD_NTD_pre_d5
# 0.012                 USD_JPD
# 0.012                 USD_NTD
# 0.012        USD_NTD_pre_dp[9
# 0.013           RMD_NTD_pre_5
# 0.014        RMD_NTD_pre_dp[5
# 0.015          USD_JPD_pre_d5
# 0.017        RMD_NTD_pre_dp[9
# 0.017           USD_NTD_pre_5
# 0.018           USD_RMB_pre_9
# 0.019            UD_USD_pre_5
# 0.023          RMD_NTD_pre_d9
# 0.026           USD_NTD_pre_9
# 0.028                 END_USD
# 0.034        USD_JPD_pre_dp[5
# 0.035          USD_JPD_pre_d9
# 0.036           UD_USD_pre_d5
# 0.041        USD_NTD_pre_dp[5
# 0.045        USD_JPD_pre_dp[9
# 0.047           RMD_NTD_pre_9
# 0.048          USD_NTD_pre_d5
# 0.063     USD_NTD_Trend_pre_9
# 0.083        USD_RMB_pre_dp[5
# 0.085  USD_NTD_Trend_pre_dp[9
# 0.095           USD_RMB_pre_5
# 0.098     USD_NTD_Trend_pre_5
# ----------------------------------------------------------------
#              precision    recall  f1-score   support
#
#         0.0       0.21      1.00      0.35        18
#         1.0       1.00      0.20      0.33        85
#
# avg / total       0.86      0.34      0.34       103
#                         feats
# 0.000  USD_NTD_Trend_pre_dp[5
# 0.000                  UD_USD
# 0.000                 USD_JPD
# 0.000                 USD_RMB
# 0.000    USD_NTD_Trend_pre_d9
# 0.000           UD_USD_pre_d9
# 0.000         UD_USD_pre_dp[5
# 0.003        USD_NTD_pre_dp[5
# 0.004     USD_NTD_Trend_pre_5
# 0.004           UD_USD_pre_d5
# 0.005            UD_USD_pre_5
# 0.007          USD_RMB_pre_d5
# 0.007           RMD_NTD_pre_5
# 0.008          USD_NTD_pre_d5
# 0.009  USD_NTD_Trend_pre_dp[9
# 0.012           USD_NTD_pre_9
# 0.013          RMD_NTD_pre_d9
# 0.013        USD_JPD_pre_dp[5
# 0.014        USD_RMB_pre_dp[5
# 0.016          USD_NTD_pre_d9
# 0.016                 USD_NTD
# 0.018          USD_JPD_pre_d5
# 0.018          USD_RMB_pre_d9
# 0.021     USD_NTD_Trend_pre_9
# 0.022                 RMD_NTD
# 0.023           USD_JPD_pre_5
# 0.024        RMD_NTD_pre_dp[9
# 0.024            UD_USD_pre_9
# 0.025        USD_JPD_pre_dp[9
# 0.029          USD_JPD_pre_d9
# 0.029           USD_JPD_pre_9
# 0.033           USD_RMB_pre_9
# 0.037           RMD_NTD_pre_9
# 0.039        RMD_NTD_pre_dp[5
# 0.041          RMD_NTD_pre_d5
# 0.041           USD_NTD_pre_5
# 0.043         UD_USD_pre_dp[9
# 0.050           USD_RMB_pre_5
# 0.051                 END_USD
# 0.054           USD_NTD_Trend
# 0.056    USD_NTD_Trend_pre_d5
# 0.061        USD_RMB_pre_dp[9
# 0.064        USD_NTD_pre_dp[9
# 0.066                  美元／南非幣
# ----------------------------------------------------------------
#              precision    recall  f1-score   support
#
#         0.0       0.07      0.06      0.06        18
#         1.0       0.81      0.85      0.83        84
#
# avg / total       0.68      0.71      0.69       102
#                         feats
# 0.000           UD_USD_pre_d9
# 0.000    USD_NTD_Trend_pre_d9
# 0.000    USD_NTD_Trend_pre_d5
# 0.000         UD_USD_pre_dp[9
# 0.000        USD_JPD_pre_dp[5
# 0.002                 USD_RMB
# 0.002        USD_RMB_pre_dp[9
# 0.003  USD_NTD_Trend_pre_dp[5
# 0.004          RMD_NTD_pre_d5
# 0.005           USD_NTD_pre_9
# 0.005          USD_JPD_pre_d5
# 0.005           USD_JPD_pre_9
# 0.006  USD_NTD_Trend_pre_dp[9
# 0.006                 RMD_NTD
# 0.006                 USD_NTD
# 0.007          USD_RMB_pre_d9
# 0.007           USD_RMB_pre_9
# 0.008           USD_JPD_pre_5
# 0.009         UD_USD_pre_dp[5
# 0.009          USD_RMB_pre_d5
# 0.009     USD_NTD_Trend_pre_9
# 0.010        USD_JPD_pre_dp[9
# 0.011            UD_USD_pre_5
# 0.014           USD_NTD_Trend
# 0.018                 USD_JPD
# 0.022           UD_USD_pre_d5
# 0.022          USD_JPD_pre_d9
# 0.025           RMD_NTD_pre_9
# 0.027           USD_RMB_pre_5
# 0.027        RMD_NTD_pre_dp[5
# 0.030        USD_NTD_pre_dp[9
# 0.030                  美元／南非幣
# 0.040                 END_USD
# 0.041                  UD_USD
# 0.045        USD_NTD_pre_dp[5
# 0.047           RMD_NTD_pre_5
# 0.048          USD_NTD_pre_d9
# 0.052           USD_NTD_pre_5
# 0.053          USD_NTD_pre_d5
# 0.054        RMD_NTD_pre_dp[9
# 0.063        USD_RMB_pre_dp[5
# 0.070     USD_NTD_Trend_pre_5
# 0.078            UD_USD_pre_9
# 0.081          RMD_NTD_pre_d9
# ----------------------------------------------------------------
#              precision    recall  f1-score   support
#
#         0.0       0.05      0.12      0.07        17
#         1.0       0.76      0.57      0.65        84
#
# avg / total       0.64      0.50      0.56       101
#                         feats
# 0.000    USD_NTD_Trend_pre_d9
# 0.000        RMD_NTD_pre_dp[9
# 0.001           USD_JPD_pre_9
# 0.001         UD_USD_pre_dp[5
# 0.003                  美元／南非幣
# 0.003            UD_USD_pre_9
# 0.003    USD_NTD_Trend_pre_d5
# 0.005           UD_USD_pre_d9
# 0.005          USD_JPD_pre_d5
# 0.006                 RMD_NTD
# 0.006          RMD_NTD_pre_d9
# 0.007  USD_NTD_Trend_pre_dp[9
# 0.007           USD_NTD_Trend
# 0.009           USD_RMB_pre_9
# 0.009        RMD_NTD_pre_dp[5
# 0.009                  UD_USD
# 0.009        USD_RMB_pre_dp[9
# 0.010         UD_USD_pre_dp[9
# 0.012        USD_NTD_pre_dp[9
# 0.014        USD_JPD_pre_dp[5
# 0.014          RMD_NTD_pre_d5
# 0.015  USD_NTD_Trend_pre_dp[5
# 0.015          USD_NTD_pre_d9
# 0.016          USD_RMB_pre_d9
# 0.019           UD_USD_pre_d5
# 0.020          USD_JPD_pre_d9
# 0.021                 USD_JPD
# 0.021            UD_USD_pre_5
# 0.022           USD_JPD_pre_5
# 0.023                 USD_RMB
# 0.024           USD_NTD_pre_9
# 0.027           USD_NTD_pre_5
# 0.033           RMD_NTD_pre_5
# 0.033           RMD_NTD_pre_9
# 0.035          USD_RMB_pre_d5
# 0.036     USD_NTD_Trend_pre_9
# 0.040        USD_JPD_pre_dp[9
# 0.046        USD_RMB_pre_dp[5
# 0.057          USD_NTD_pre_d5
# 0.066           USD_RMB_pre_5
# 0.069     USD_NTD_Trend_pre_5
# 0.076                 END_USD
# 0.077                 USD_NTD
# 0.078        USD_NTD_pre_dp[5
# ----------------------------------------------------------------
#              precision    recall  f1-score   support
#
#         0.0       0.07      0.14      0.10        14
#         1.0       0.76      0.59      0.67        64
#
# avg / total       0.64      0.51      0.56        78
#                         feats
# 0.000            UD_USD_pre_5
# 0.000                 RMD_NTD
# 0.000                  UD_USD
# 0.000     USD_NTD_Trend_pre_9
# 0.000    USD_NTD_Trend_pre_d9
# 0.003  USD_NTD_Trend_pre_dp[9
# 0.003  USD_NTD_Trend_pre_dp[5
# 0.005           UD_USD_pre_d9
# 0.005                 USD_RMB
# 0.005                 USD_JPD
# 0.006        RMD_NTD_pre_dp[9
# 0.007          USD_RMB_pre_d5
# 0.011          USD_NTD_pre_d9
# 0.012          USD_NTD_pre_d5
# 0.013     USD_NTD_Trend_pre_5
# 0.015          USD_RMB_pre_d9
# 0.017           UD_USD_pre_d5
# 0.017                 USD_NTD
# 0.018        USD_NTD_pre_dp[5
# 0.018          USD_JPD_pre_d5
# 0.020           USD_RMB_pre_5
# 0.021           RMD_NTD_pre_9
# 0.021         UD_USD_pre_dp[9
# 0.021          USD_JPD_pre_d9
# 0.022        USD_JPD_pre_dp[9
# 0.022            UD_USD_pre_9
# 0.023           RMD_NTD_pre_5
# 0.025          RMD_NTD_pre_d9
# 0.025           USD_JPD_pre_9
# 0.027                  美元／南非幣
# 0.027         UD_USD_pre_dp[5
# 0.028                 END_USD
# 0.035           USD_NTD_pre_9
# 0.036        USD_JPD_pre_dp[5
# 0.038        USD_RMB_pre_dp[9
# 0.041           USD_RMB_pre_9
# 0.044           USD_NTD_pre_5
# 0.047        RMD_NTD_pre_dp[5
# 0.048           USD_JPD_pre_5
# 0.049        USD_RMB_pre_dp[5
# 0.050          RMD_NTD_pre_d5
# 0.051        USD_NTD_pre_dp[9
# 0.051           USD_NTD_Trend
# 0.070    USD_NTD_Trend_pre_d5
# ----------------------------------------------------------------
#              precision    recall  f1-score   support
#
#         0.0       0.12      0.08      0.10        13
#         1.0       0.82      0.89      0.85        63
#
# avg / total       0.70      0.75      0.73        76
#                         feats
# 0.000           UD_USD_pre_d5
# 0.000        USD_RMB_pre_dp[5
# 0.000          USD_RMB_pre_d5
# 0.000         UD_USD_pre_dp[9
# 0.000                 USD_RMB
# 0.000        USD_JPD_pre_dp[9
# 0.000    USD_NTD_Trend_pre_d9
# 0.002        USD_JPD_pre_dp[5
# 0.002         UD_USD_pre_dp[5
# 0.002          USD_JPD_pre_d9
# 0.002          RMD_NTD_pre_d9
# 0.002                 USD_NTD
# 0.005           USD_NTD_pre_9
# 0.005           USD_JPD_pre_9
# 0.005  USD_NTD_Trend_pre_dp[5
# 0.006          RMD_NTD_pre_d5
# 0.006                 RMD_NTD
# 0.007                 USD_JPD
# 0.009           USD_RMB_pre_9
# 0.009     USD_NTD_Trend_pre_9
# 0.009           UD_USD_pre_d9
# 0.010  USD_NTD_Trend_pre_dp[9
# 0.011    USD_NTD_Trend_pre_d5
# 0.011          USD_NTD_pre_d9
# 0.012          USD_JPD_pre_d5
# 0.020          USD_NTD_pre_d5
# 0.021           RMD_NTD_pre_9
# 0.023                  UD_USD
# 0.026           USD_NTD_Trend
# 0.030                 END_USD
# 0.032                  美元／南非幣
# 0.034        RMD_NTD_pre_dp[9
# 0.034            UD_USD_pre_5
# 0.034        USD_NTD_pre_dp[5
# 0.039        USD_RMB_pre_dp[9
# 0.046           USD_JPD_pre_5
# 0.048        RMD_NTD_pre_dp[5
# 0.050          USD_RMB_pre_d9
# 0.056           USD_NTD_pre_5
# 0.057           RMD_NTD_pre_5
# 0.069           USD_RMB_pre_5
# 0.070        USD_NTD_pre_dp[9
# 0.093            UD_USD_pre_9
# 0.103     USD_NTD_Trend_pre_5
# ----------------------------------------------------------------
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00        13
#         1.0       0.82      0.95      0.88        63
#
# avg / total       0.68      0.79      0.73        76
#                         feats
# 0.000    USD_NTD_Trend_pre_d9
# 0.000           USD_RMB_pre_9
# 0.000         UD_USD_pre_dp[9
# 0.004  USD_NTD_Trend_pre_dp[9
# 0.004        USD_JPD_pre_dp[5
# 0.004            UD_USD_pre_5
# 0.005           USD_NTD_pre_9
# 0.006           UD_USD_pre_d9
# 0.006          RMD_NTD_pre_d5
# 0.006           UD_USD_pre_d5
# 0.007         UD_USD_pre_dp[5
# 0.008          USD_JPD_pre_d5
# 0.009          USD_NTD_pre_d9
# 0.010        USD_RMB_pre_dp[9
# 0.010        RMD_NTD_pre_dp[9
# 0.010           USD_RMB_pre_5
# 0.011           USD_JPD_pre_9
# 0.012                 USD_RMB
# 0.012                 END_USD
# 0.014           RMD_NTD_pre_9
# 0.014           RMD_NTD_pre_5
# 0.016           USD_JPD_pre_5
# 0.016          USD_JPD_pre_d9
# 0.017                 USD_JPD
# 0.019           USD_NTD_Trend
# 0.019                 USD_NTD
# 0.021                 RMD_NTD
# 0.021    USD_NTD_Trend_pre_d5
# 0.025          USD_NTD_pre_d5
# 0.026            UD_USD_pre_9
# 0.032        USD_NTD_pre_dp[9
# 0.034          USD_RMB_pre_d5
# 0.035     USD_NTD_Trend_pre_9
# 0.035        USD_NTD_pre_dp[5
# 0.040        RMD_NTD_pre_dp[5
# 0.042          USD_RMB_pre_d9
# 0.042                  美元／南非幣
# 0.043           USD_NTD_pre_5
# 0.043          RMD_NTD_pre_d9
# 0.046        USD_JPD_pre_dp[9
# 0.049                  UD_USD
# 0.069        USD_RMB_pre_dp[5
# 0.073  USD_NTD_Trend_pre_dp[5
# 0.083     USD_NTD_Trend_pre_5
# ----------------------------------------------------------------
#              precision    recall  f1-score   support
#
#         0.0       0.27      0.31      0.29        13
#         1.0       0.85      0.83      0.84        63
#
# avg / total       0.75      0.74      0.74        76
#                         feats
# 0.000  USD_NTD_Trend_pre_dp[9
# 0.000    USD_NTD_Trend_pre_d9
# 0.002        USD_JPD_pre_dp[5
# 0.002           USD_RMB_pre_9
# 0.003           UD_USD_pre_d9
# 0.004    USD_NTD_Trend_pre_d5
# 0.006           USD_JPD_pre_9
# 0.006          USD_RMB_pre_d5
# 0.007        USD_RMB_pre_dp[9
# 0.008         UD_USD_pre_dp[9
# 0.008          USD_JPD_pre_d5
# 0.009                 RMD_NTD
# 0.011           UD_USD_pre_d5
# 0.011  USD_NTD_Trend_pre_dp[5
# 0.012           USD_NTD_Trend
# 0.012        RMD_NTD_pre_dp[9
# 0.013          USD_NTD_pre_d9
# 0.014          RMD_NTD_pre_d5
# 0.016           RMD_NTD_pre_9
# 0.017        USD_JPD_pre_dp[9
# 0.018         UD_USD_pre_dp[5
# 0.018                  UD_USD
# 0.019                 USD_NTD
# 0.020           USD_NTD_pre_9
# 0.021                  美元／南非幣
# 0.022           USD_JPD_pre_5
# 0.023          USD_RMB_pre_d9
# 0.025          RMD_NTD_pre_d9
# 0.026        USD_NTD_pre_dp[9
# 0.026                 USD_JPD
# 0.027           USD_NTD_pre_5
# 0.030        USD_NTD_pre_dp[5
# 0.031          USD_JPD_pre_d9
# 0.032     USD_NTD_Trend_pre_9
# 0.034           USD_RMB_pre_5
# 0.037            UD_USD_pre_5
# 0.038        RMD_NTD_pre_dp[5
# 0.038        USD_RMB_pre_dp[5
# 0.039           RMD_NTD_pre_5
# 0.041            UD_USD_pre_9
# 0.042                 USD_RMB
# 0.058     USD_NTD_Trend_pre_5
# 0.078          USD_NTD_pre_d5
# 0.096                 END_USD

# %%
set(y_2days)
# Out:
# {1.0}

# %%
a = GradientBoostingClassifier()

# %%
class Node(object):
    def __init__(self):
        self.l = None 
        self.r = None
        self.rule = {}
    
class DecisionTree():
    def __init__(self):
        pass
    def greedy_construct(self):
        pass

# %%
'../sct/data/'

# %%
import os

import numpy
from numpy.distutils.misc_util import Configuration


def configuration(parent_package="", top_path=None):
    config = Configuration("tree", parent_package, top_path)
    libraries = []
    if os.name == 'posix':
        libraries.append('m')
    config.add_extension("_tree",
                         sources=["_tree.pyx"],
                         include_dirs=[numpy.get_include()],
                         libraries=libraries,
                         extra_compile_args=["-O3"])
    config.add_extension("_splitter",
                         sources=["_splitter.pyx"],
                         include_dirs=[numpy.get_include()],
                         libraries=libraries,
                         extra_compile_args=["-O3"])
    config.add_extension("_criterion",
                         sources=["_criterion.pyx"],
                         include_dirs=[numpy.get_include()],
                         libraries=libraries,
                         extra_compile_args=["-O3"])
    config.add_extension("_utils",
                         sources=["_utils.pyx"],
                         include_dirs=[numpy.get_include()],
                         libraries=libraries,
                         extra_compile_args=["-O3"])

    config.add_subpackage("tests")

    return config


from numpy.distutils.core import setup
setup(**configuration().todict())
# Out:
# non-existing path in '': '_tree.pyx'
# non-existing path in '': '_splitter.pyx'
# non-existing path in '': '_criterion.pyx'
# non-existing path in '': '_utils.pyx'
# Warning: Assuming default configuration (tests/{setup_tests,setup}.py was not found)
# ----------------------------------------------------------------------
# ValueError                           Traceback (most recent call last)
# <ipython-input-355-33d57f285b80> in <module>()
#      37
#      38 from numpy.distutils.core import setup
# ---> 39 setup(**configuration().todict())
#
# <ipython-input-355-33d57f285b80> in configuration(parent_package, top_path)
#      31                          extra_compile_args=["-O3"])
#      32
# ---> 33     config.add_subpackage("tests")
#      34
#      35     return config
#
# /Users/kentchiu/anaconda/lib/python3.6/site-packages/numpy/distutils/misc_util.py in add_subpackage(self, subpackage_name, subpackage_path, standalone)
#    1022         config_list = self.get_subpackage(subpackage_name, subpackage_path,
#    1023                                           parent_name = parent_name,
# -> 1024                                           caller_level = 2)
#    1025         if not config_list:
#    1026             self.warn('No configuration returned, assuming unavailable.')
#
# /Users/kentchiu/anaconda/lib/python3.6/site-packages/numpy/distutils/misc_util.py in get_subpackage(self, subpackage_name, subpackage_path, parent_name, caller_level)
#     984             config = Configuration(subpackage_name, parent_name,
#     985                                    self.top_path, subpackage_path,
# --> 986                                    caller_level = caller_level+1)
#     987         else:
#     988             config = self._get_configuration_from_setup_py(
#
# /Users/kentchiu/anaconda/lib/python3.6/site-packages/numpy/distutils/misc_util.py in __init__(self, package_name, parent_name, top_path, package_path, caller_level, setup_name, **attrs)
#     766             package_path = njoin(self.local_path, package_path)
#     767         if not os.path.isdir(package_path or '.'):
# --> 768             raise ValueError("%r is not a directory" % (package_path,))
#     769         self.top_path = top_path
#     770         self.package_path = package_path
#
# ValueError: 'tests' is not a directory
